# %% [markdown]
# # Max Cut
#
# - https://learning.quantum.ibm.com/tutorial/quantum-approximate-optimization-algorithm#step-1-map-classical-inputs-to-a-quantum-problem

# %%
import rustworkx as rx
from rustworkx.visualization import mpl_draw as draw_graph
import numpy as np

n = 5

graph = rx.PyGraph()
graph.add_nodes_from(np.arange(0, n, 1))
edge_list = [(0, 1, 1.0), (0, 2, 1.0), (0, 4, 1.0), (1, 2, 1.0), (2, 3, 1.0), (3, 4, 1.0)]
graph.add_edges_from(edge_list)
draw_graph(graph, node_size=600, with_labels=True)

# %%
from qiskit.quantum_info import SparsePauliOp
def build_max_cut_paulis(graph: rx.PyGraph) -> list[tuple[str, float]]:
    """Convert the graph to Pauli list.

    This function does the inverse of `build_max_cut_graph`
    """
    pauli_list = []
    for edge in list(graph.edge_list()):
        paulis = ["I"] * len(graph)
        paulis[edge[0]], paulis[edge[1]] = "Z", "Z"

        weight = graph.get_edge_data(edge[0], edge[1])

        pauli_list.append(("".join(paulis)[::-1], weight))

    return pauli_list


max_cut_paulis = build_max_cut_paulis(graph)

cost_hamiltonian = SparsePauliOp.from_list(max_cut_paulis)
print("Cost Function Hamiltonian:", cost_hamiltonian)
# Out:
# Cost Function Hamiltonian: SparsePauliOp(['IIIZZ', 'IIZIZ', 'ZIIIZ', 'IIZZI', 'IZZII', 'ZZIII'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])

# %%
from qiskit.circuit.library import QAOAAnsatz

circuit = QAOAAnsatz(cost_operator=cost_hamiltonian, reps=2)
circuit.measure_all()

circuit.draw('mpl')

# %%
circuit.parameters
# Out:
# ParameterView([ParameterVectorElement(β[0]), ParameterVectorElement(β[1]), ParameterVectorElement(γ[0]), ParameterVectorElement(γ[1])])

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

service = QiskitRuntimeService(channel='ibm_quantum')
backend = service.least_busy(min_num_qubits=127)
print(backend)

pm = generate_preset_pass_manager(optimization_level=3,
                                    backend=backend)

candidate_circuit = pm.run(circuit)
candidate_circuit.draw('mpl', fold=False, idle_wires=False)
# Out:
# /tmp/ipykernel_169424/886047420.py:4: DeprecationWarning: The "ibm_quantum" channel option is deprecated and will be sunset on 1 July. After this date, "ibm_cloud", "ibm_quantum_platform", and "local" will be the only valid channels. Open Plan users should migrate now.  All other users should review the migration guide (https://quantum.cloud.ibm.com/docs/migration-guides/classic-iqp-to-cloud-iqp)to learn when to migrate.
#   service = QiskitRuntimeService(channel='ibm_quantum')
# <IBMBackend('ibm_sherbrooke')>

# %%
initial_gamma = np.pi
initial_beta = np.pi/2
init_params = [initial_gamma, initial_beta, initial_gamma, initial_beta]

# %%
def cost_func_estimator(params, ansatz, hamiltonian, estimator):

    # transform the observable defined on virtual qubits to
    # an observable defined on all physical qubits
    isa_hamiltonian = hamiltonian.apply_layout(ansatz.layout)

    pub = (ansatz, isa_hamiltonian, params)
    job = estimator.run([pub])

    results = job.result()[0]
    cost = results.data.evs

    objective_func_vals.append(cost)


    return cost

# %%
from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from scipy.optimize import minimize

objective_func_vals = [] # Global variable
with Session(backend=backend) as session:
    # If using qiskit-ibm-runtime<0.24.0, change `mode=` to `session=`
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 1000

    # Set simple error suppression/mitigation options
    estimator.options.dynamical_decoupling.enable = True
    estimator.options.dynamical_decoupling.sequence_type = "XY4"
    estimator.options.twirling.enable_gates = True
    estimator.options.twirling.num_randomizations = "auto"

    result = minimize(
        cost_func_estimator,
        init_params,
        args=(candidate_circuit, cost_hamiltonian, estimator),
        method="COBYLA",
        tol=1e-2,
    )
    print(result)
# Out:
# /home/marcio/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:1129: UserWarning: IBM Quantum Platform is moving, and this version will be sunset on July 1. To get started on the new platform, read the migration guide at https://docs.quantum.ibm.com/migration-guides/classic-iqp-to-cloud-iqp
#   warnings.warn(warning_message)
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# IBMRuntimeError                           Traceback (most recent call last)
# Cell In[12], line 16
#      13 estimator.options.twirling.enable_gates = True
#      14 estimator.options.twirling.num_randomizations = "auto"
# ---> 16 result = minimize(
#      17     cost_func_estimator,
#      18     init_params,
#      19     args=(candidate_circuit, cost_hamiltonian, estimator),
#      20     method="COBYLA",
#      21     tol=1e-2,
#      22 )
#      23 print(result)
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/scipy/optimize/_minimize.py:744, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#     743 elif meth == 'cobyla':
# --> 744     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     745                            bounds=bounds, **options)
#     746 elif meth == 'cobyqa':
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:326, in ScalarFunction.fun(self, x)
#     324 if not np.array_equal(x, self.x):
#     325     self._update_x(x)
# --> 326 self._update_fun()
#     327 return self.f
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# Cell In[11], line 8, in cost_func_estimator(params, ansatz, hamiltonian, estimator)
#       5 isa_hamiltonian = hamiltonian.apply_layout(ansatz.layout)
#       7 pub = (ansatz, isa_hamiltonian, params)
# ----> 8 job = estimator.run([pub])
#      10 results = job.result()[0]
#      11 cost = results.data.evs
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/qiskit_ibm_runtime/estimator.py:150, in EstimatorV2.run(self, pubs, precision)
#     148 coerced_pubs = [EstimatorPub.coerce(pub, precision) for pub in pubs]
#     149 validate_estimator_pubs(coerced_pubs)
# --> 150 return self._run(coerced_pubs)
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/qiskit_ibm_runtime/base_primitive.py:176, in BasePrimitiveV2._run(self, pubs)
#     174 # Batch or Session
#     175 if self._mode:
# --> 176     return self._mode._run(
#     177         program_id=self._program_id(),
#     178         inputs=primitive_inputs,
#     179         options=runtime_options,
#     180         callback=options_dict.get("environment", {}).get("callback", None),
#     181         result_decoder=DEFAULT_DECODERS.get(self._program_id()),
#     182     )
#     184 if self._backend:
#     185     if get_cm_session():
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:42, in _active_session.<locals>._wrapper(self, *args, **kwargs)
#      40 if not self._active:
#      41     raise IBMRuntimeError("The session is closed.")
# ---> 42 return func(self, *args, **kwargs)
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:172, in Session._run(self, program_id, inputs, options, callback, result_decoder)
#     169 options["backend"] = self._backend
#     171 if isinstance(self._service, QiskitRuntimeService):
# --> 172     job = self._service._run(
#     173         program_id=program_id,  # type: ignore[arg-type]
#     174         options=options,
#     175         inputs=inputs,
#     176         session_id=self._session_id,
#     177         start_session=False,
#     178         callback=callback,
#     179         result_decoder=result_decoder,
#     180     )
#     182     if self._backend is None:
#     183         self._backend = job.backend()
#
# File ~/repositories/personal/qc-examples/venv/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:1134, in QiskitRuntimeService._run(self, program_id, inputs, options, callback, result_decoder, session_id, start_session)
#    1132     if ex.status_code == 404:
#    1133         raise RuntimeProgramNotFound(f"Program not found: {ex.message}") from None
# -> 1134     raise IBMRuntimeError(f"Failed to run program: {ex}") from None
#    1136 if response["backend"] and response["backend"] != qrt_options.get_backend_name():
#    1137     backend = self.backend(name=response["backend"], instance=hgp_name)
#
# IBMRuntimeError: 'Failed to run program: \'400 Client Error: Bad Request for url: https://api.quantum.ibm.com/runtime/jobs. {"errors":[{"code":1217,"message":"Session has been closed.","solution":"Reduce time between submitting subsequent jobs in a session.","more_info":"https://docs.quantum-computing.ibm.com/errors"}]}\''
